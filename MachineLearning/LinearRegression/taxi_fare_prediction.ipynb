# %%
import pandas as pd 
import numpy as np 
import matplotlib.pyplot as plt

# %%
taxi_data = pd.read_csv("taxi_trip_pricing.csv")

# %%
taxi_data.head()
# Out:
#    Trip_Distance_km Time_of_Day Day_of_Week  Passenger_Count  \
# 0             19.35     Morning     Weekday              3.0
# 1             47.59   Afternoon     Weekday              1.0
# 2             36.87     Evening     Weekend              1.0
# 3             30.33     Evening     Weekday              4.0
# 4               NaN     Evening     Weekday              3.0
#
#   Traffic_Conditions Weather  Base_Fare  Per_Km_Rate  Per_Minute_Rate  \
# 0                Low   Clear       3.56         0.80             0.32
# 1               High   Clear        NaN         0.62             0.43
# 2               High   Clear       2.70         1.21             0.15
# 3                Low     NaN       3.48         0.51             0.15
# 4               High   Clear       2.93         0.63             0.32
#
#    Trip_Duration_Minutes  Trip_Price
# 0                  53.82     36.2624
# 1                  40.57         NaN
# 2                  37.27     52.9032
# ...

# %%
taxi_data.isnull().sum()
# Out:
# Trip_Distance_km         50
# Time_of_Day              50
# Day_of_Week              50
# Passenger_Count          50
# Traffic_Conditions       50
# Weather                  50
# Base_Fare                50
# Per_Km_Rate              50
# Per_Minute_Rate          50
# Trip_Duration_Minutes    50
# Trip_Price               49
# dtype: int64

# %%
taxi_data.dropna(inplace=True)

# %%
taxi_data.head()
# Out:
#     Trip_Distance_km Time_of_Day Day_of_Week  Passenger_Count  \
# 0              19.35     Morning     Weekday              3.0
# 2              36.87     Evening     Weekend              1.0
# 5               8.64   Afternoon     Weekend              2.0
# 12             41.79       Night     Weekend              3.0
# 14              9.91     Evening     Weekday              2.0
#
#    Traffic_Conditions Weather  Base_Fare  Per_Km_Rate  Per_Minute_Rate  \
# 0                 Low   Clear       3.56         0.80             0.32
# 2                High   Clear       2.70         1.21             0.15
# 5              Medium   Clear       2.55         1.71             0.48
# 12               High   Clear       4.60         1.77             0.11
# 14               High   Clear       2.32         1.26             0.34
#
#     Trip_Duration_Minutes  Trip_Price
# 0                   53.82     36.2624
# 2                   37.27     52.9032
# 5                   89.33     60.2028
# ...

# %%
taxi_data.isnull().sum()
# Out:
# Trip_Distance_km         0
# Time_of_Day              0
# Day_of_Week              0
# Passenger_Count          0
# Traffic_Conditions       0
# Weather                  0
# Base_Fare                0
# Per_Km_Rate              0
# Per_Minute_Rate          0
# Trip_Duration_Minutes    0
# Trip_Price               0
# dtype: int64

# %%
from sklearn.preprocessing import LabelEncoder
encode = LabelEncoder()

# %%
taxi_data.head()
# Out:
#     Trip_Distance_km Time_of_Day Day_of_Week  Passenger_Count  \
# 0              19.35     Morning     Weekday              3.0
# 2              36.87     Evening     Weekend              1.0
# 5               8.64   Afternoon     Weekend              2.0
# 12             41.79       Night     Weekend              3.0
# 14              9.91     Evening     Weekday              2.0
#
#    Traffic_Conditions Weather  Base_Fare  Per_Km_Rate  Per_Minute_Rate  \
# 0                 Low   Clear       3.56         0.80             0.32
# 2                High   Clear       2.70         1.21             0.15
# 5              Medium   Clear       2.55         1.71             0.48
# 12               High   Clear       4.60         1.77             0.11
# 14               High   Clear       2.32         1.26             0.34
#
#     Trip_Duration_Minutes  Trip_Price
# 0                   53.82     36.2624
# 2                   37.27     52.9032
# 5                   89.33     60.2028
# ...

# %%
taxi_data.head().dtypes
# Out:
# Trip_Distance_km         float64
# Time_of_Day               object
# Day_of_Week               object
# Passenger_Count          float64
# Traffic_Conditions        object
# Weather                   object
# Base_Fare                float64
# Per_Km_Rate              float64
# Per_Minute_Rate          float64
# Trip_Duration_Minutes    float64
# Trip_Price               float64
# dtype: object

# %%
for col in taxi_data.select_dtypes("object"):
    taxi_data[col] = encode.fit_transform(taxi_data[col])

# %%
taxi_data.head()
# Out:
#     Trip_Distance_km  Time_of_Day  Day_of_Week  Passenger_Count  \
# 0              19.35            2            0              3.0
# 2              36.87            1            1              1.0
# 5               8.64            0            1              2.0
# 12             41.79            3            1              3.0
# 14              9.91            1            0              2.0
#
#     Traffic_Conditions  Weather  Base_Fare  Per_Km_Rate  Per_Minute_Rate  \
# 0                    1        0       3.56         0.80             0.32
# 2                    0        0       2.70         1.21             0.15
# 5                    2        0       2.55         1.71             0.48
# 12                   0        0       4.60         1.77             0.11
# 14                   0        0       2.32         1.26             0.34
#
#     Trip_Duration_Minutes  Trip_Price
# 0                   53.82     36.2624
# 2                   37.27     52.9032
# ...

# %%
X = taxi_data.iloc[:,:-1]
y = taxi_data.iloc[:,-1]

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test = train_test_split(X,y,train_size=0.2,random_state=90)

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()

# %%
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

# %%
from sklearn.linear_model import LinearRegression
model = LinearRegression()

# %%
model.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
y_pred = model.predict(X_test)

# %%
residuals = y_pred - y_test

# %%
import seaborn as sns 
sns.displot(residuals,kind='kde')
