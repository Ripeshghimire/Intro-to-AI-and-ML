# %%
import pandas as pd 
import numpy as np 
import matplotlib.pyplot as plt

# %%
taxi_data = pd.read_csv("taxi_trip_pricing.csv")

# %% [markdown]
# # Load the dataset
# # check if the dataset has null values or not
# #

# %%
taxi_data.head()
# Out:
#    Trip_Distance_km Time_of_Day Day_of_Week  Passenger_Count  \
# 0             19.35     Morning     Weekday              3.0
# 1             47.59   Afternoon     Weekday              1.0
# 2             36.87     Evening     Weekend              1.0
# 3             30.33     Evening     Weekday              4.0
# 4               NaN     Evening     Weekday              3.0
#
#   Traffic_Conditions Weather  Base_Fare  Per_Km_Rate  Per_Minute_Rate  \
# 0                Low   Clear       3.56         0.80             0.32
# 1               High   Clear        NaN         0.62             0.43
# 2               High   Clear       2.70         1.21             0.15
# 3                Low     NaN       3.48         0.51             0.15
# 4               High   Clear       2.93         0.63             0.32
#
#    Trip_Duration_Minutes  Trip_Price
# 0                  53.82     36.2624
# 1                  40.57         NaN
# 2                  37.27     52.9032
# ...

# %%
taxi_data.isnull().sum()
# Out:
# Trip_Distance_km         0
# Time_of_Day              0
# Day_of_Week              0
# Passenger_Count          0
# Traffic_Conditions       0
# Weather                  0
# Base_Fare                0
# Per_Km_Rate              0
# Per_Minute_Rate          0
# Trip_Duration_Minutes    0
# Trip_Price               0
# dtype: int64

# %%
taxi_data.dropna(inplace=True)

# %%
taxi_data.head()
# Out:
#     Trip_Distance_km Time_of_Day Day_of_Week  Passenger_Count  \
# 0              19.35     Morning     Weekday              3.0
# 2              36.87     Evening     Weekend              1.0
# 5               8.64   Afternoon     Weekend              2.0
# 12             41.79       Night     Weekend              3.0
# 14              9.91     Evening     Weekday              2.0
#
#    Traffic_Conditions Weather  Base_Fare  Per_Km_Rate  Per_Minute_Rate  \
# 0                 Low   Clear       3.56         0.80             0.32
# 2                High   Clear       2.70         1.21             0.15
# 5              Medium   Clear       2.55         1.71             0.48
# 12               High   Clear       4.60         1.77             0.11
# 14               High   Clear       2.32         1.26             0.34
#
#     Trip_Duration_Minutes  Trip_Price
# 0                   53.82     36.2624
# 2                   37.27     52.9032
# 5                   89.33     60.2028
# ...

# %%
taxi_data['Time_of_Day'].unique()
# Out:
# array([2, 1, 0, 3])

# %%
from sklearn.preprocessing import LabelEncoder
encoder = LabelEncoder()

# %%
taxi_data["Time_of_Day"] = encoder.fit_transform(taxi_data["Time_of_Day"])

# %%
for col in taxi_data.select_dtypes("object"):
# Out:
#     Day_of_Week Traffic_Conditions Weather
# 0       Weekday                Low   Clear
# 2       Weekend               High   Clear
# 5       Weekend             Medium   Clear
# 12      Weekend               High   Clear
# 14      Weekday               High   Clear
# ..          ...                ...     ...
# 990     Weekday                Low   Clear
# 992     Weekday             Medium   Clear
# 994     Weekday             Medium   Clear
# 995     Weekend             Medium   Clear
# 998     Weekday                Low   Clear
#
# [562 rows x 3 columns]

# %% [markdown]
#  make a for loop
#
#  select object type
#
# transform the object type data to int using label encoder

# %%
taxi_data.head()
# Out:
#     Trip_Distance_km  Time_of_Day Day_of_Week  Passenger_Count  \
# 0              19.35            2     Weekday              3.0
# 2              36.87            1     Weekend              1.0
# 5               8.64            0     Weekend              2.0
# 12             41.79            3     Weekend              3.0
# 14              9.91            1     Weekday              2.0
#
#    Traffic_Conditions Weather  Base_Fare  Per_Km_Rate  Per_Minute_Rate  \
# 0                 Low   Clear       3.56         0.80             0.32
# 2                High   Clear       2.70         1.21             0.15
# 5              Medium   Clear       2.55         1.71             0.48
# 12               High   Clear       4.60         1.77             0.11
# 14               High   Clear       2.32         1.26             0.34
#
#     Trip_Duration_Minutes  Trip_Price
# 0                   53.82     36.2624
# 2                   37.27     52.9032
# 5                   89.33     60.2028
# ...
